# %% [markdown]
# # Prepare_brfss_data_for_hackathon
#
# Prepare package to be shared on Github:
#
# Please note the complete packages is XXXX GB. Please download **before** hackathon on USB.
#
# Folder BRFSS:
# 1. brfss_level_1.csv : size = (10000 rows, 16 cols) decoded
# 2. brfss_level_2.csv : size = (10000 rows, 48 cols) decoded
# 3. LLCP2019.csv      : size = (418268 rows, 342 cols) **coded**
# 4. brfss2019_sample_raw.csv : size = (1000 rows, 15 cols) **coded**
# 4. explore_brfss_getting_started.ipynb : Notebook to get started with analysing #1 and #2
# 5. BRFSS2019_decodingtabs_simplified.xlsx : contains decoding tables for each interview question (only required when analyzing LLCP2019.csv)
# 6. colnames.xlsx : contains decoding table for column names (only required when analyzing LLCP2019.csv)
#
# For more information on 2019 BRFSS Survey Data and Documentation, see:
# * https://www.cdc.gov/brfss/annual_data/2019/pdf/codebook19_llcp-v2-508.HTML
# * https://www.cdc.gov/brfss/annual_data/annual_2019.html
#
# Folder CBS
# 1. This is a set
# 2. other set
# 3. an another again

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from os.path import join

plt.style.use('ggplot')

# %% [markdown]
# # 1. Settings

# %%
 
data_dir = '/home/pieter/projects/brfss/data'  # Linux

SAMPLE_SEED = 342367
SAMPLE_SIZE = 10000

# %% [markdown]
# # Data inladen

# %%
# BFRSS enquete data
brfss_raw = pd.read_csv(join(data_dir, 'LLCP2019.csv'), sep='|')

# Decoderingstabellen
decoderingstabellen = pd.read_excel(join(data_dir, 'BRFSS2019_decodingtabs_simplified.xlsx'), sheet_name=None)

# Beschrijving kolomnamen
col_description = pd.read_excel(join(data_dir, 'colnames.xlsx'))

# %%
brfss_raw.shape
# Out:
# (418268, 342)

# %%
# Random sample
brfss = brfss_raw.sample(n=SAMPLE_SIZE, random_state=SAMPLE_SEED)

# %%
# Decode column names
mapping_colnames = dict(zip(col_description.variable_name, col_description.label))

# %%
# Select columns

# selected_cols = col_description[col_description.include_level_2 == 1]['variable_name'].to_list()
selected_cols = col_description[col_description.include_level_1 == 1]['variable_name'].to_list()

ddf = brfss[selected_cols].apply(pd.to_numeric, downcast='integer')

# %%
ddf.shape
# Out:
# (10000, 15)

# %%
decoding_cell_mapper = dict()

for col in ddf.columns:
    value = pd.to_numeric(decoderingstabellen[col]['Value'], downcast='integer', errors='ignore')
    label = decoderingstabellen[col]['Value Label']
    decoding_cell_mapper[col] = dict(zip(value, label))

# %%
mapping_colnames_2 = {'Reported_Weight_in_Pounds' : 'Reported_Weight_in_Kilograms',
                      'Reported_Height_in_Feet_and_Inches' : 'Reported_Height_in_Meters',
                      'How_Many_Times_Walking,_Running,_Jogging,_or_Swimming_NR1': 'How_Many_Times_per_Month_Walking_Running_etc',
                      'Minutes_or_Hours_Walking,_Running,_Jogging,_or_Swimming_NR1': 'Hours_Walking,_Running,_Jogging,_or_Swimming',
                      'How_many_times_did_you_eat_fruit?' : 'How_many_times_did_you_eat_fruit_per_month?',
                      'How_many_times_did_you_eat_dark_green_vegetables?' : 'How_many_times_did_you_eat_dark_green_vegetables_per_week?' }

# %%
### Finally, we got a human readible showcase dataset!
data = ddf.replace(decoding_cell_mapper).rename(columns=mapping_colnames).rename(columns=mapping_colnames_2)

# %%
# Review each data column has a rather nice distribution

for col in data.columns:
    print('\n*** {} ***'.format(col))
    print(data[col].value_counts())

# %%
data['ID'] = data.index
data.sort_index(inplace=True)
data.to_csv('/home/pieter/projects/brfss/data/brfss_level_1.csv', sep='|', index=False)

# %%
df2 = pd.read_csv('/home/pieter/projects/brfss/data/brfss_level_2.csv', sep='|')

# %%
df.shape
# Out:
# (10000, 16)

# %%
df
# Out:
#      Sex_of_Respondent General_Health Have_any_health_care_coverage  \
# 0                    M      Very good                           Yes
# 1                    F      Very good                           Yes
# 2                    F           Good                            No
# 3                    M           Good                           Yes
# 4                    F      Excellent                           Yes
# ...                ...            ...                           ...
# 9995                 F      Excellent                           Yes
# 9996                 F           Good                           Yes
# 9997                 F           Good                           Yes
# 9998                 M           Fair                           Yes
# 9999                 M           Good                           Yes
#
#      Could_Not_See_Doctor_Because_of_Cost  \
# 0                                      No
# 1                                      No
# 2                                      No
# 3                                      No
# 4                                      No
# ...                                   ...
# 9995                                   No
# 9996                                  Yes
# 9997                                   No
# 9998                                   No
# 9999                                   No
#
#      Length_of_time_since_last_routine_checkup Ever_Told_Blood_Pressure_High  \
# 0                                 [0, 1) years          Not asked or Missing
# 1                                 [0, 1) years                           Yes
# 2                                 [1, 2) years          Not asked or Missing
# 3                                 [1, 2) years               Borderline high
# 4                                 [0, 1) years          Not asked or Missing
# ...                                        ...                           ...
# 9995                              [0, 1) years          Not asked or Missing
# 9996                              [0, 1) years                           Yes
# 9997                              [0, 1) years                           Yes
# 9998                              [0, 1) years                           Yes
# 9999                              [1, 2) years          Not asked or Missing
#
#      Marital_Status                     Education_Level Own_or_Rent_Home  \
# 0          Divorced                  6 College graduate       Group home
# 1           Widowed  5 Some college or technical school       Group home
# 2           Married              4 High school graduate       Group home
# 3           Married              4 High school graduate             Rent
# 4           Married                  6 College graduate       Group home
# ...             ...                                 ...              ...
# 9995  Never married                  6 College graduate       Group home
# 9996  Never married                  6 College graduate             Rent
# 9997        Married              4 High school graduate       Group home
# 9998        Married                        2 Elementary       Group home
# 9999  Never married  5 Some college or technical school             Rent
#
#        Employment_Status Reported_Weight_in_Kilograms  \
# 0                Retired                        113.4
# 1            A homemaker                        72.57
# 2            A homemaker                      Refused
# 3                Retired                       127.01
# 4     Employed for wages                        68.04
# ...                  ...                          ...
# 9995  Employed for wages                        72.57
# 9996         A homemaker                        98.88
# 9997             Retired                        77.11
# 9998             Retired                         63.5
# 9999           A student                        81.65
#
#      Smoked_at_Least_100_Cigarettes Frequency_of_Days_Now_Smoking  \
# 0                               Yes                     Every day
# 1                                No          Not asked or Missing
# 2                                No          Not asked or Missing
# 3                               Yes                    Not at all
# 4                               Yes                    Not at all
# ...                             ...                           ...
# 9995                             No          Not asked or Missing
# 9996                            Yes                    Not at all
# 9997                             No          Not asked or Missing
# 9998            Don’t know/Not Sure          Not asked or Missing
# 9999                            Yes                    Not at all
#
#      Days_in_past_30_had_alcoholic_beverage  \
# 0                                      25.0
# 1                                         0
# 2                                         0
# 3                                         0
# 4                                       5.0
# ...                                     ...
# 9995                                    2.0
# 9996                                      0
# 9997                                      0
# 9998                                      0
# 9999                                    1.0
#
#      How_many_times_did_you_eat_fruit_per_month?      ID
# 0                                           30.0       6
# 1                                           30.0     166
# 2                                          Never     271
# 3                                           56.0     296
# 4                                           60.0     373
# ...                                          ...     ...
# 9995                                       Never  417904
# 9996                                        60.0  417984
# 9997                                         7.0  417987
# 9998                                        30.0  418229
# 9999                                        30.0  418246
#
# [10000 rows x 16 columns]

# %%
df2.head()
# Out:
#   State_FIPS_Code Sex_of_Respondent General_Health  \
# 0         Alabama                 M      Very good
# 1         Alabama                 F      Very good
# 2         Alabama                 F           Good
# 3         Alabama                 M           Good
# 4         Alabama                 F      Excellent
#
#   Have_any_health_care_coverage Multiple_Health_Care_Professionals  \
# 0                           Yes                      Yes, only one
# 1                           Yes                      Yes, only one
# 2                            No                                 No
# 3                           Yes                      Yes, only one
# 4                           Yes                      More than one
#
#   Could_Not_See_Doctor_Because_of_Cost  \
# 0                                   No
# 1                                   No
# 2                                   No
# 3                                   No
# 4                                   No
#
#   Length_of_time_since_last_routine_checkup Ever_Told_Blood_Pressure_High  \
# 0                              [0, 1) years          Not asked or Missing
# 1                              [0, 1) years                           Yes
# 2                              [1, 2) years          Not asked or Missing
# 3                              [1, 2) years               Borderline high
# 4                              [0, 1) years          Not asked or Missing
#
#   Currently_Taking_Blood_Pressure_Medication  \
# 0                                  Not asked
# 1                                        Yes
# 2                                  Not asked
# 3                                  Not asked
# 4                                  Not asked
#
#   How_Long_since_Cholesterol_Checked  ...  \
# 0                        [0, 1) year  ...
# 1                        [0, 1) year  ...
# 2                        [1, 2) year  ...
# 3                        [1, 2) year  ...
# 4                        [0, 1) year  ...
#
#   Hours_Walking,_Running,_Jogging,_or_Swimming  \
# 0                                         0.75
# 1                         Not asked or Missing
# 2                                          2.0
# 3                         Not asked or Missing
# 4                                          2.5
#
#   How_many_times_did_you_eat_fruit_per_month?  \
# 0                                        30.0
# 1                                        30.0
# 2                                       Never
# 3                                        56.0
# 4                                        60.0
#
#   How_many_times_did_you_eat_dark_green_vegetables_per_week?  \
# 0                                              Never
# 1                                                7.0
# 2                                               3.75
# 3                                                3.0
# 4                                                3.0
#
#   Adult_flu_shot/spray_past_12_mos Computed_Race-Ethnicity_grouping  \
# 0                              Yes                            White
# 1                              Yes                            White
# 2             Not asked or Missing                            White
# 3             Not asked or Missing                            White
# 4             Not asked or Missing                            Black
#
#   Calculated_sex_variable  \
# 0                    Male
# 1                  Female
# 2                  Female
# 3                    Male
# 4                  Female
#
#   Reported_age_in_five-year_age_categories_calculated_variable  \
# 0                                       Age 70 to 74
# 1                                       Age 75 to 79
# 2                                       Age 55 to 59
# 3                                       Age 70 to 74
# 4                                       Age 45 to 49
#
#    Computed_Smoking_Status               Physical_Activity_Index   ID
# 0  Current Frequent Smoker          Meet Aerobic Recommendations    6
# 1             Never Smoked  Did Not Meet Aerobic Recommendations  166
# 2             Never Smoked          Meet Aerobic Recommendations  271
# 3            Former Smoker  Did Not Meet Aerobic Recommendations  296
# 4            Former Smoker          Meet Aerobic Recommendations  373
#
# [5 rows x 48 columns]

# %%
df2.Reported_Weight_in_Kilograms
# Out:
# 0         113.4
# 1         72.57
# 2       Refused
# 3        127.01
# 4         68.04
#          ...
# 9995      72.57
# 9996      98.88
# 9997      77.11
# 9998       63.5
# 9999      81.65
# Name: Reported_Weight_in_Kilograms, Length: 10000, dtype: object
